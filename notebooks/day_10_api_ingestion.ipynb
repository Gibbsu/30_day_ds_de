# %% [markdown]
# Hour 1 — What Is an API?

# %%
import pandas as pd

# %% [markdown]
# API       → way applications communicate
#
# Request   → your program asks for something
#
# Response  → server sends something back
#
# JSON      → common format for API data
#
# Endpoint  → specific API location/resource
#
# GET       → request data

# %%
order = {
    "order_id": 1001,
    "product": "Laptop",
    "quantity": 2,
    "price": 1200
}

# %% [markdown]
# Without me giving you the syntax, retrieve only the value "Laptop" from order.

# %%
order["product"]
# Out:
# 'Laptop'

# %% [markdown]
# Nested JSON

# %%
api_response = {
    "status": "success",
    "data": {
        "order_id": 1001,
        "customer": {
            "customer_id": 1,
            "customer_name": "Alex"
        },
        "product": {
            "product_id": 101,
            "product_name": "Laptop"
        },
        "quantity": 2,
        "price": 1200
    }
}

# %% [markdown]
# Retrieve:
#
# Laptop

# %%
api_response["data"]["product"]["product_name"]
# Out:
# 'Laptop'

# %% [markdown]
# Lists of Records

# %%
orders = [
    {
        "order_id": 1001,
        "product": "Laptop",
        "quantity": 1,
        "price": 1200
    },
    {
        "order_id": 1002,
        "product": "Monitor",
        "quantity": 2,
        "price": 300
    },
    {
        "order_id": 1003,
        "product": "Keyboard",
        "quantity": 3,
        "price": 100
    }
]

# %% [markdown]
# Retrieve:
#
# Monitor

# %%
orders[1]["product"]
# Out:
# 'Monitor'

# %% [markdown]
# JSON → Pandas

# %% [markdown]
# Convert the entire orders list into a Pandas DataFrame and store it as:

# %%
orders_df = pd.DataFrame(orders)

# %%
display(orders_df)
# Out:
#    order_id   product  quantity  price
# 0      1001    Laptop         1   1200
# 1      1002   Monitor         2    300
# 2      1003  Keyboard         3    100

# %%
orders_df["total_sales"] = orders_df["quantity"] * orders_df["price"]

# %%
display(orders_df)
# Out:
#    order_id   product  quantity  price  total_sales
# 0      1001    Laptop         1   1200         1200
# 1      1002   Monitor         2    300          600
# 2      1003  Keyboard         3    100          300

# %% [markdown]
# Hour 2 — Making an Actual API Request

# %%
import requests

# %% [markdown]
# Now make your first GET request.

# %%
url = "https://jsonplaceholder.typicode.com/posts"

response = requests.get(url)

# %% [markdown]
# url        → where the API resource lives
# requests   → Python library sending the request
# .get()     → asks the API for data
# response   → what the server sends back

# %% [markdown]
# Check whether the request succeeded by running:

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# Reading the Response

# %% [markdown]
# The API sent JSON, so we can convert its response body into Python with:

# %%
response.json()
# Out:
# [{'userId': 1,
#   'id': 1,
#   'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit',
#   'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'},
#  {'userId': 1,
#   'id': 2,
#   'title': 'qui est esse',
#   'body': 'est rerum tempore vitae\nsequi sint nihil reprehenderit dolor beatae ea dolores neque\nfugiat blanditiis voluptate porro vel nihil molestiae ut reiciendis\nqui aperiam non debitis possimus qui neque nisi nulla'},
#  {'userId': 1,
#   'id': 3,
#   'title': 'ea molestias quasi exercitationem repellat qui ipsa sit aut',
#   'body': 'et iusto sed quo iure\nvoluptatem occaecati omnis eligendi aut ad\nvoluptatem doloribus vel accusantium quis pariatur\nmolestiae porro eius odio et labore et velit aut'},
#  {'userId': 1,
#   'id': 4,
#   'title': 'eum et est occaecati',
# ...

# %%
posts = response.json()

# %% [markdown]
# What type of Python object is posts?

# %%
type(posts)
# Out:
# list

# %% [markdown]
# Retrieve the entire first dictionary from posts.

# %%
posts[0]
# Out:
# {'userId': 1,
#  'id': 1,
#  'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit',
#  'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'}

# %% [markdown]
# Now retrieve only the title from the first post.

# %%
posts[0]["title"]
# Out:
# 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit'

# %% [markdown]
# API → DataFrame

# %% [markdown]
# Convert the entire posts API response into a Pandas DataFrame called:

# %%
posts_df = pd.DataFrame(posts)

# %%
posts_df.head()
# Out:
#    userId  id                                              title  \
# 0       1   1  sunt aut facere repellat provident occaecati e...
# 1       1   2                                       qui est esse
# 2       1   3  ea molestias quasi exercitationem repellat qui...
# 3       1   4                               eum et est occaecati
# 4       1   5                                 nesciunt quas odio
#
#                                                 body
# 0  quia et suscipit\nsuscipit recusandae consequu...
# 1  est rerum tempore vitae\nsequi sint nihil repr...
# 2  et iusto sed quo iure\nvoluptatem occaecati om...
# 3  ullam et saepe reiciendis voluptatem adipisci\...
# 4  repudiandae veniam quaerat sunt sed\nalias aut...

# %% [markdown]
# If the API returns an HTTP error, Python raises an exception and stops that part of the pipeline.

# %%
response = requests.get(url)
response.raise_for_status()

posts = response.json()

# %% [markdown]
# Let's intentionally make a bad request.

# %%
bad_url = "https://jsonplaceholder.typicode.com/invalid_endpoint"

# %%
bad_response = requests.get(bad_url)

# %%
bad_response.status_code
# Out:
# 404

# %%
bad_response.raise_for_status()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 bad_response.raise_for_status()
#
# File ~\OneDrive\Desktop\30 Day DS DE\venv\Lib\site-packages\requests\models.py:1167, in Response.raise_for_status(self)
#    1162     http_error_msg = (
#    1163         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1164     )
#    1166 if http_error_msg:
# -> 1167     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://jsonplaceholder.typicode.com/invalid_endpoint

# %% [markdown]
# You should get an HTTP error instead of letting the pipeline continue silently.

# %% [markdown]
# Build a Reusable API Function

# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
sys.path.append(str(project_root))

# %%
import importlib
import src.pipeline

importlib.reload(src.pipeline)
# Out:
# <module 'src.pipeline' from 'c:\\Users\\gilbe\\OneDrive\\Desktop\\30 Day DS DE\\src\\pipeline.py'>

# %%
from src.pipeline import extract_api_data

# %% [markdown]
# Test Your Function

# %%
api_data = extract_api_data(url)

# %%
type(api_data)
# Out:
# list

# %%
importlib.reload(src.pipeline)

from src.pipeline import extract_api_data, transform_api_data

# %% [markdown]
# Then use those functions to produce a DataFrame called:
#
# api_df

# %%
api_df = transform_api_data(api_data)

# %% [markdown]
# Hour 4 — Build an API Pipeline

# %%
importlib.reload(src.pipeline)

from src.pipeline import extract_api_data, transform_api_data, run_api_pipeline

# %%
data_dir = project_root / "data"

# %%
api_output_path = data_dir / "day_10_api_posts.csv"

# %%
api_pipeline_df = run_api_pipeline(url,api_output_path)
# Out:
# 2026-09-03 11:11:40,496 - INFO - Starting API pipeline
# 2026-09-03 11:11:40,781 - INFO - Loading API data
# 2026-09-03 11:11:40,786 - INFO - API pipeline completed

# %%
api_output_path.exists()
# Out:
# True

# %%
api_pipeline_df.shape
# Out:
# (100, 4)

# %%
api_pipeline_df.head()
# Out:
#    userId  id                                              title  \
# 0       1   1  sunt aut facere repellat provident occaecati e...
# 1       1   2                                       qui est esse
# 2       1   3  ea molestias quasi exercitationem repellat qui...
# 3       1   4                               eum et est occaecati
# 4       1   5                                 nesciunt quas odio
#
#                                                 body
# 0  quia et suscipit\nsuscipit recusandae consequu...
# 1  est rerum tempore vitae\nsequi sint nihil repr...
# 2  et iusto sed quo iure\nvoluptatem occaecati om...
# 3  ullam et saepe reiciendis voluptatem adipisci\...
# 4  repudiandae veniam quaerat sunt sed\nalias aut...
